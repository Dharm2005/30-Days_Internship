# %% [markdown]
# ### Task 3: Column Selection and Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/student.csv")

# %%
display(df["Marks"])
# Out:
# 0    78
# 1    34
# 2    56
# 3    89
# 4    42
# 5    91
# Name: Marks, dtype: int64

# %%
display(df[["Name", "Marks"]])
# Out:
#      Name  Marks
# 0    Amit     78
# 1    Neha     34
# 2    Ravi     56
# 3   Pooja     89
# 4   Karan     42
# 5  Anjali     91

# %%
display(df.loc[0:2, ["Name", "Marks"]])
# Out:
#    Name  Marks
# 0  Amit     78
# 1  Neha     34
# 2  Ravi     56
