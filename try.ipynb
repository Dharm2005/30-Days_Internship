# %%
import pandas as pd

# %%
df = pd.read_csv("./Day - 26 - Mini Project – Data Cleaning (13-2-26 FRI)/data/clean/day-26.csv")

# %%
df.head()
# Out:
#               race  gender      age admission_type discharge_disposition  \
# 0        Caucasian  Female   [0-10)        Unknown               Unknown
# 1        Caucasian  Female  [10-20)      Emergency    Discharged to home
# 2  AfricanAmerican  Female  [20-30)      Emergency    Discharged to home
# 3        Caucasian    Male  [30-40)      Emergency    Discharged to home
# 4        Caucasian    Male  [40-50)      Emergency    Discharged to home
#
#      admission_source  time_in_hospital payer_code medical_specialty  \
# 0  Physician Referral                 1    Unknown             Other
# 1      Emergency Room                 3    Unknown           Unknown
# 2      Emergency Room                 2    Unknown           Unknown
# 3      Emergency Room                 2    Unknown           Unknown
# 4      Emergency Room                 1    Unknown           Unknown
#
#    num_lab_procedures  ...  citoglipton  insulin  glyburide-metformin  \
# ...
