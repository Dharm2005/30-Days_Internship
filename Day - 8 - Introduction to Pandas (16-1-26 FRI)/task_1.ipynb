# %% [markdown]
# ### Task 1: Creating Series and DataFrame

# %%
import pandas as pd

# %%
marks_series = pd.Series([78, 34, 56, 89, 42])
print("Series:\n", marks_series)
# Out:
# Series:
#  0    78
# 1    34
# 2    56
# 3    89
# 4    42
# dtype: int64

# %%
df = pd.read_csv("./data/student.csv")
display(df)
# Out:
#    StudentID    Name  Age Gender  Marks  Attendance
# 0          1    Amit   21      M     78          85
# 1          2    Neha   22      F     34          60
# 2          3    Ravi   20      M     56          75
# 3          4   Pooja   23      F     89          90
# 4          5   Karan   21      M     42          65
# 5          6  Anjali   22      F     91          95
